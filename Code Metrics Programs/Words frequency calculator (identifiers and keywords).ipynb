# %%
import os
from collections import Counter
import re
import numpy as np
import pandas as pd


if __name__ == '__main__':

	#Directory containing files to search:
    directory = 'D:/TCD/Dissertation/learningdata/classrepdistributed/'

    count = 0
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)

        with open(filepath, 'r') as fp:
            print (filename)
            text = fp.read()
            p = re.compile(r"\w+")
            ex = re.findall(p,text)
            c = Counter(ex)
            print(c.items())
            print("\n")
# Out:
# AdderSub.v
# dict_items([('module', 1), ('AdderSub', 1), ('sum_diff', 3), ('carry', 3), ('A', 4), ('B', 4), ('select', 3), ('output', 2), ('3', 2), ('0', 2), ('input', 2), ('assign', 1), ('endmodule', 1)])
#
#
# Circuit_1.v
# dict_items([('timescale', 1), ('1ns', 1), ('100ps', 1), ('default_nettype', 1), ('none', 1), ('module', 1), ('Circuit_1', 1), ('A', 6), ('B', 6), ('C', 6), ('F1', 3), ('F2', 4), ('output', 1), ('input', 1), ('wire', 1), ('T1', 3), ('T2', 3), ('T3', 3), ('w1', 3), ('w2', 3), ('w3', 3), ('w4', 3), ('and', 1), ('G1', 1), ('G3', 1), ('G4', 1), ('G5', 1), ('G8', 1), ('or', 1), ('G2', 1), ('G6', 1), ('G9', 1), ('not', 1), ('G7', 1), ('endmodule', 1)])
#
#
# Circuit_2.v
# dict_items([('timescale', 1), ('1ns', 1), ('100ps', 1), ('default_nettype', 1), ('none', 1), ('module', 1), ('Circuit_2', 1), ('Out_1', 3), ('Out_2', 3), ('Out_3', 3), ('A', 5), ('B', 7), ('C', 9), ('D', 7), ('output', 1), ('input', 1), ('assign', 3), ('endmodule', 1)])
#
#
# Compare.v
# ...

# %%
import os
from collections import Counter
import re
import numpy as np
import pandas as pd


if __name__ == '__main__':

	#Directory containing files to search:
    directory = 'D:/TCD/Dissertation/learningdata/results/special-orig/'

    count = 0
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)

        with open(filepath, 'r') as fp:
            print (filename)
            text = fp.read()
            p = re.compile(r"\w+")
            ex = re.findall(p,text)
            print(set(ex),len(ex))
            c = Counter(ex)
            print(c.items())
            print("\n")
# Out:
# CIRC-AdderSub.v
# {'sum_diff', 'AdderSub', 'output', 'A', '3', 'endmodule', 'B', 'module', 'select', '0', 'input', 'carry', 'assign'} 29
# dict_items([('module', 1), ('AdderSub', 1), ('sum_diff', 3), ('carry', 3), ('A', 4), ('B', 4), ('select', 3), ('output', 2), ('3', 2), ('0', 2), ('input', 2), ('assign', 1), ('endmodule', 1)])
#
#
# CIRC-Circuit_1.v
# {'100ps', 'G1', 'G4', 'B', 'T3', 'w2', 'T1', 'timescale', 'not', 'output', 'A', 'G9', 'T2', 'C', 'Circuit_1', 'and', 'F1', '1ns', 'F2', 'G2', 'wire', 'G7', 'G3', 'G5', 'or', 'input', 'G8', 'w3', 'w1', 'G6', 'endmodule', 'default_nettype', 'module', 'none', 'w4'} 69
# ...

# %%
import os
from collections import Counter
import re
import numpy as np
import pandas as pd


if __name__ == '__main__':

	#Directory containing files to search:
    directory = 'D:/TCD/Dissertation/learningdata/anonymiseddata/Anon submissions/'

    count = 0
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)

        with open(filepath, 'r', encoding="utf8") as fp:
            print (filename)
            text = fp.read()
            p = re.compile(r"\w+")
            ex = re.findall(p,text)
            c = Counter(ex)
            print(c.items())
            print("\n")
# Out:
# Anon-002-submit-2019-01-23-07-45-00-455551334.txt
# dict_items([('submit', 1), ('Anon', 1), ('002', 1), ('Circuit_1', 2), ('v', 1), ('module', 1), ('A', 6), ('B', 6), ('C', 6), ('F1', 3), ('F2', 4), ('output', 1), ('input', 1), ('wire', 1), ('T1', 3), ('T2', 3), ('T3', 3), ('T4', 3), ('T5', 3), ('T6', 3), ('T7', 3), ('and', 5), ('G1', 1), ('or', 3), ('G2', 1), ('G3', 1), ('G4', 1), ('G5', 1), ('G6', 1), ('not', 1), ('G7', 1), ('G8', 1), ('G9', 1), ('endmodule', 1)])
#
#
# Anon-002-submit-2019-01-28-13-20-15-630103207.txt
# dict_items([('submit', 1), ('Anon', 1), ('002', 1), ('Circuit_2', 2), ('v', 1), ('module', 1), ('Out_1', 3), ('Out_2', 3), ('Out_3', 3), ('A', 5), ('B', 7), ('C', 9), ('D', 7), ('input', 1), ('output', 1), ('assign', 1), ('endmodule', 1)])
#
#
# Anon-002-submit-2019-01-28-13-21-54-1171215609.txt
# ...
