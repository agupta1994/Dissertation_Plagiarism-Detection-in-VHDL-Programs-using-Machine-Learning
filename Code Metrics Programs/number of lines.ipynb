# %%
import os

def countlines(start, lines=0, header=True, begin_start=None):
    if header:
        print('{:>10} |{:>10} | {:<20}'.format('ADDED', 'TOTAL', 'FILE'))
        print('{:->11}|{:->11}|{:->20}'.format('', '', ''))

    for thing in os.listdir(start):
        thing = os.path.join(start, thing)
        if os.path.isfile(thing):
            if thing.endswith('.v'):
                with open(thing, 'r') as f:
                    newlines = f.readlines()
                    newlines = len(newlines)
                    lines += newlines

                    if begin_start is not None:
                        reldir_of_thing = '.' + thing.replace(begin_start, '')
                    else:
                        reldir_of_thing = '.' + thing.replace(start, '')

                    print('{:>10} |{:>10} | {:<20}'.format(
                            newlines, lines, reldir_of_thing))


    for thing in os.listdir(start):
        thing = os.path.join(start, thing)
        if os.path.isdir(thing):
            lines = countlines(thing, lines, header=False, begin_start=start)

    return lines

# %%
countlines(r'D:/TCD/Dissertation/learningdata/classrepdistributed/')
# Out:
#      ADDED |     TOTAL | FILE
# -----------|-----------|--------------------
#         10 |        10 | .AdderSub.v
#         12 |        22 | .Circuit_1.v
#         12 |        34 | .Circuit_2.v
#         14 |        48 | .Compare.v
#         22 |        70 | .Counter_1.v
#         26 |        96 | .DecimalAdder.v
#         35 |       131 | .FiniteStateMachine.v
#         22 |       153 | .OddFunction.v
#         20 |       173 | .StateDiagram.v
#         24 |       197 | .UDP_Majority_4.v
# 197

# %%
countlines(r'D:/TCD/Dissertation/learningdata/results/latest-orig/')
# Out:
#      ADDED |     TOTAL | FILE
# -----------|-----------|--------------------
#         18 |        18 | .002-Circuit_1.v
#         14 |        32 | .002-Circuit_2.v
#         10 |        42 | .003-AdderSub.v
#         11 |        53 | .003-Circuit_1.v
#          8 |        61 | .003-Circuit_2.v
#         15 |        76 | .003-Compare.v
#         22 |        98 | .003-Counter_1.v
#         26 |       124 | .003-DecimalAdder.v
#         35 |       159 | .003-FiniteStateMachine.v
#         22 |       181 | .003-OddFunction.v
#         29 |       210 | .003-SerialComplementer.v
#         20 |       230 | .003-StateDiagram.v
#         24 |       254 | .003-UDP_Majority_4.v
#         10 |       264 | .004-AdderSub.v
#         15 |       279 | .004-Circuit_1.v
#          8 |       287 | .004-Circuit_2.v
#         11 |       298 | .004-Compare.v
#         22 |       320 | .004-Counter_1.v
#         23 |       343 | .004-DecimalAdder.v
#         35 |       378 | .004-FiniteStateMachine.v
# ...

# %%
countlines(r'D:/TCD/Dissertation/learningdata/results/special-orig/')
# Out:
#      ADDED |     TOTAL | FILE
# -----------|-----------|--------------------
#         10 |        10 | .CIRC-AdderSub.v
#         12 |        22 | .CIRC-Circuit_1.v
#         12 |        34 | .CIRC-Circuit_2.v
#         14 |        48 | .CIRC-Compare.v
#         22 |        70 | .CIRC-Counter_1.v
#         26 |        96 | .CIRC-DecimalAdder.v
#         35 |       131 | .CIRC-FiniteStateMachine.v
#         22 |       153 | .CIRC-OddFunction.v
#         20 |       173 | .CIRC-StateDiagram.v
#         24 |       197 | .CIRC-UDP_Majority_4.v
#          6 |       203 | .INST-AdderSub.v
#         15 |       218 | .INST-Circuit_1.v
#         15 |       233 | .INST-Circuit_2.v
#         16 |       249 | .INST-Compare.v
#         16 |       265 | .INST-Counter_1.v
#         21 |       286 | .INST-DecimalAdder.v
#         17 |       303 | .INST-FiniteStateMachine.v
#         22 |       325 | .INST-OddFunction.v
#         25 |       350 | .INST-SerialComplementer.v
# ...

# %%
import os

def countlines(start, lines=0, header=True, begin_start=None):
    if header:
        print('{:>10} |{:>10} | {:<20}'.format('ADDED', 'TOTAL', 'FILE'))
        print('{:->11}|{:->11}|{:->20}'.format('', '', ''))

    for thing in os.listdir(start):
        thing = os.path.join(start, thing)
        if os.path.isfile(thing):
            if thing.endswith('.txt'):
                with open(thing, 'r', encoding="utf8") as f:
                    newlines = f.readlines()
                    newlines = len(newlines)
                    lines += newlines

                    if begin_start is not None:
                        reldir_of_thing = '.' + thing.replace(begin_start, '')
                    else:
                        reldir_of_thing = '.' + thing.replace(start, '')

                    print('{:>10} |{:>10} | {:<20}'.format(
                            newlines, lines, reldir_of_thing))


    for thing in os.listdir(start):
        thing = os.path.join(start, thing)
        if os.path.isdir(thing):
            lines = countlines(thing, lines, header=False, begin_start=start)

    return lines

# %%
countlines(r'D:/TCD/Dissertation/learningdata/anonymiseddata/Anon submissions/')
# Out:
#      ADDED |     TOTAL | FILE
# -----------|-----------|--------------------
#         19 |        19 | .Anon-002-submit-2019-01-23-07-45-00-455551334.txt
#          6 |        25 | .Anon-002-submit-2019-01-28-13-20-15-630103207.txt
#          6 |        31 | .Anon-002-submit-2019-01-28-13-21-54-1171215609.txt
#          6 |        37 | .Anon-002-submit-2019-01-28-13-26-29-1231105803.txt
#          8 |        45 | .Anon-002-submit-2019-01-28-13-28-09-1955736607.txt
#          8 |        53 | .Anon-002-submit-2019-01-28-13-29-46-1601838031.txt
#         12 |        65 | .Anon-002-submit-2019-01-28-13-41-14-1461149096.txt
#         12 |        77 | .Anon-002-submit-2019-01-28-13-42-44-2106445659.txt
#         12 |        89 | .Anon-002-submit-2019-01-28-13-44-16-723152465.txt
#          8 |        97 | .Anon-002-submit-2019-01-28-13-45-07-333884973.txt
#         13 |       110 | .Anon-002-submit-2019-01-28-13-57-42-1988501780.txt
# ...
